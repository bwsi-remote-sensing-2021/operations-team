# %%
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
try:
    from torchvision import transforms, utils
except:
    # !conda install --yes torchvision --no-channel-priority
    from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
try:
    from torchvision import transforms, utils
except:
    # !pip install torchvision
    from torchvision import transforms, utils
from PIL import Image

import warnings
warnings.filterwarnings("ignore")

# %%
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 50

# %%
ladiDataImport = pd.read_csv("http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_aggregated_responses_url.tsv",delimiter='\t',header='infer')

# %%
# Strip off bracket and comma from the Answer catagory
ladiDataImport["Answer"] = ladiDataImport["Answer"].str.strip('[|]')
# split list of responses into multiple rows
ladiDataImport["Answer"] = ladiDataImport["Answer"].str.split(",",expand = True)
# remove the single quote character from either end of string
ladiDataImport["Answer"] = ladiDataImport["Answer"].str.strip('\'')
# add a column to help with aggregation when pivoting
ladiDataImport["response_count"] = 1
# Create a matrix with the number of workers who answered given label for given image
# using pivot table; filling in nan values with 0
label_matrix = ladiDataImport.pivot_table(values='response_count', 
                                          index='url', 
                                          columns='Answer', 
                                          aggfunc='sum',
                                          fill_value=0)

# %%
#labels = ['infrastructure:bridge','infrastructure:building','infrastructure:dam-levee','infrastructure:none','infrastructure:railway','infrastructure:road','infrastructure:utility-line']
#labelsWithoutNone = ['infrastructure:bridge','infrastructure:building','infrastructure:dam-levee','infrastructure:railway','infrastructure:road','infrastructure:utility-line']
#communication tower,no pipe,no water tower
labels = ['infrastructure:bridge','infrastructure:building','infrastructure:none','infrastructure:road']
labelsWithoutNone = ['infrastructure:bridge','infrastructure:building','infrastructure:road']
#communication tower,no pipe,no water tower

def filterRows(row):

    arr = [row[x] for x in labels]
    return arr.count(0)

def proc(row): 
    arr = [row[x] for x in labelsWithoutNone]
    if row['infrastructure:none'] > max(arr):
#         print('true')
#         print(row)
        for x in labelsWithoutNone:
            row[x] = 0
        row['infrastructure:none'] = 1
    else:
#         print('false')
#         print(row)
        row['infrastructure:none'] = 0
        for x in labelsWithoutNone:
            if row[x] > 0: row[x] = 1
    return row
    

infrastructure_matrix = label_matrix[labels]
infrastructure_matrix = infrastructure_matrix[infrastructure_matrix.apply(filterRows,axis=1) != len(labels)]
infrastructure_matrix = infrastructure_matrix.apply(proc,axis =1)
# m= label_matrix[['infrastructure:bridge','infrastructure:building','infrastructure:dam-levee','infrastructure:none','infrastructure:railway','infrastructure:road','infrastructure:utility-line']]
# m = m[m.apply(filterRows,axis=1) != len(labels)]
# m.head(1000)
# infrastructure_matrix = infrastructure_matrix[infrastructure_matrix.apply(filterRows,axis=1) != 6]
# for i in labels:
#     print("")
#     print(i)
#     print(infrastructure_matrix[infrastructure_matrix[i] != 0].count())
#     print("")
# #1982 bridges
# #6294 buildings
# #65 comm towers 
# #137 dam-levees 
# #3325 none
# #101 pipe
# #108 railway
# #1609 road
# #192 utility line
# #75 water tower

# %%
sample_size=1200
samples = infrastructure_matrix[infrastructure_matrix['infrastructure:bridge'] == 1].sample(sample_size)
for col in infrastructure_matrix.columns[1:]:
    samples = samples.append(infrastructure_matrix[infrastructure_matrix[col] == 1].sample(sample_size))
samples = samples.reset_index().drop_duplicates(subset='url', keep='first').set_index('url')

# %%
metadata_csv = 'infrastructure_sample_metadata.csv'
label_csv = 'infrastructure_sample_label.csv'

# %%
# Load ladi_images_metadata.csv
metadata = pd.read_csv('http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_images_metadata.csv')

# sampling
# sample_size=1000
# flood_sample = flood_examples.sample(sample_size)
# non_flood_sample = non_flood_examples.sample(sample_size)

# creating a df with True/False labels for flooding
# training_flood = pd.DataFrame(index=flood_sample.index, data={'label':True}).reset_index()
# training_non_flood = pd.DataFrame(index=non_flood_sample.index, data={'label':False}).reset_index()
# label_df = pd.concat([training_flood, training_non_flood], ignore_index=True)

samples.to_csv(label_csv)

# create list of urls to download
samples.reset_index()['url'].to_csv('infrastructure_urls_to_download.csv', index=False, header=False)

#get metada
infrastructure_metadata = metadata[metadata['url'].isin(samples.index)]
# flood_metadata = metadata[metadata['url'].isin(flood_sample.index)]
# not_flood_metadata = metadata[metadata['url'].isin(non_flood_sample.index)]
# training_metadata = pd.concat([flood_metadata, not_flood_metadata], ignore_index=True)

infrastructure_metadata.to_csv(metadata_csv)

# %%
# !mkdir -p training_images
# !wget --content-disposition --trust-server-names -i infrastructure__to_download.csv -P training_images/
# Out:
# --2021-07-31 17:14:05--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615182/DSC_1098_928ca14d-8a78-46f2-8268-ade3d7b4644a.jpg
# Resolving ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)... 52.218.224.1
# Connecting to ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)|52.218.224.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7437762 (7.1M) [image/jpeg]
# Saving to: ‘training_images/DSC_1098_928ca14d-8a78-46f2-8268-ade3d7b4644a.jpg’
#
# DSC_1098_928ca14d-8 100%[===================>]   7.09M  15.0MB/s    in 0.5s
#
# 2021-07-31 17:14:06 (15.0 MB/s) - ‘training_images/DSC_1098_928ca14d-8a78-46f2-8268-ade3d7b4644a.jpg’ saved [7437762/7437762]
#
# --2021-07-31 17:14:06--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616222/FEMA_REG_5d8e4494-f1fc-4aac-80ba-4f47f3ba7f04.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5855795 (5.6M) [image/jpeg]
# Saving to: ‘training_images/FEMA_REG_5d8e4494-f1fc-4aac-80ba-4f47f3ba7f04.jpg.1’
#
# FEMA_REG_5d8e4494-f 100%[===================>]   5.58M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:06 (38.5 MB/s) - ‘training_images/FEMA_REG_5d8e4494-f1fc-4aac-80ba-4f47f3ba7f04.jpg.1’ saved [5855795/5855795]
#
# --2021-07-31 17:14:06--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614001/A0027-91_ee0541d9-c677-4635-87b4-b3536db0c353.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7899110 (7.5M) [image/jpeg]
# Saving to: ‘training_images/A0027-91_ee0541d9-c677-4635-87b4-b3536db0c353.jpg’
#
# A0027-91_ee0541d9-c 100%[===================>]   7.53M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:06 (50.6 MB/s) - ‘training_images/A0027-91_ee0541d9-c677-4635-87b4-b3536db0c353.jpg’ saved [7899110/7899110]
#
# --2021-07-31 17:14:06--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613864/DSC_0361_1f58e037-a38d-400a-aa2c-b6f82f144c4f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7154504 (6.8M) [image/jpeg]
# Saving to: ‘training_images/DSC_0361_1f58e037-a38d-400a-aa2c-b6f82f144c4f.jpg.1’
#
# DSC_0361_1f58e037-a 100%[===================>]   6.82M  24.7MB/s    in 0.3s
#
# 2021-07-31 17:14:07 (24.7 MB/s) - ‘training_images/DSC_0361_1f58e037-a38d-400a-aa2c-b6f82f144c4f.jpg.1’ saved [7154504/7154504]
#
# --2021-07-31 17:14:07--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614001/A0027-91_0f834f50-3ce2-4bf3-b626-6709881ed9ef.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8606312 (8.2M) [image/jpeg]
# Saving to: ‘training_images/A0027-91_0f834f50-3ce2-4bf3-b626-6709881ed9ef.jpg’
#
# A0027-91_0f834f50-3 100%[===================>]   8.21M  26.4MB/s    in 0.3s
#
# 2021-07-31 17:14:07 (26.4 MB/s) - ‘training_images/A0027-91_0f834f50-3ce2-4bf3-b626-6709881ed9ef.jpg’ saved [8606312/8606312]
#
# --2021-07-31 17:14:07--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615470/DSC_0813_b26e521a-e5de-41af-9db3-3ea5459c06fc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14365102 (14M) [image/jpeg]
# Saving to: ‘training_images/DSC_0813_b26e521a-e5de-41af-9db3-3ea5459c06fc.jpg’
#
# DSC_0813_b26e521a-e 100%[===================>]  13.70M  22.8MB/s    in 0.6s
#
# 2021-07-31 17:14:08 (22.8 MB/s) - ‘training_images/DSC_0813_b26e521a-e5de-41af-9db3-3ea5459c06fc.jpg’ saved [14365102/14365102]
#
# --2021-07-31 17:14:08--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/613990/A0013V-0_d16eb2b8-9c63-432c-b7fd-16242b516e25.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3496697 (3.3M) [image/jpeg]
# Saving to: ‘training_images/A0013V-0_d16eb2b8-9c63-432c-b7fd-16242b516e25.jpg’
#
# A0013V-0_d16eb2b8-9 100%[===================>]   3.33M  14.4MB/s    in 0.2s
#
# 2021-07-31 17:14:08 (14.4 MB/s) - ‘training_images/A0013V-0_d16eb2b8-9c63-432c-b7fd-16242b516e25.jpg’ saved [3496697/3496697]
#
# --2021-07-31 17:14:08--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7969_43061603-2856-47c9-b7fc-611a6d9d3ab0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14014901 (13M) [image/jpeg]
# Saving to: ‘training_images/DSC_7969_43061603-2856-47c9-b7fc-611a6d9d3ab0.jpg’
#
# DSC_7969_43061603-2 100%[===================>]  13.37M  43.2MB/s    in 0.3s
#
# 2021-07-31 17:14:09 (43.2 MB/s) - ‘training_images/DSC_7969_43061603-2856-47c9-b7fc-611a6d9d3ab0.jpg’ saved [14014901/14014901]
#
# --2021-07-31 17:14:09--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614104/A0084_AP_68c21135-b532-40d9-90fe-d75311531b54.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9280131 (8.8M) [image/jpeg]
# Saving to: ‘training_images/A0084_AP_68c21135-b532-40d9-90fe-d75311531b54.jpg’
#
# A0084_AP_68c21135-b 100%[===================>]   8.85M  36.9MB/s    in 0.2s
#
# 2021-07-31 17:14:09 (36.9 MB/s) - ‘training_images/A0084_AP_68c21135-b532-40d9-90fe-d75311531b54.jpg’ saved [9280131/9280131]
#
# --2021-07-31 17:14:09--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613608/DSC_1846_434689c2-ff55-4df6-b554-2a4e793ce674.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9279813 (8.8M) [image/jpeg]
# Saving to: ‘training_images/DSC_1846_434689c2-ff55-4df6-b554-2a4e793ce674.jpg.2’
#
# DSC_1846_434689c2-f 100%[===================>]   8.85M  23.0MB/s    in 0.4s
#
# 2021-07-31 17:14:10 (23.0 MB/s) - ‘training_images/DSC_1846_434689c2-ff55-4df6-b554-2a4e793ce674.jpg.2’ saved [9279813/9279813]
#
# --2021-07-31 17:14:10--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613770/DSC_4339_4e245e6c-c89c-48ce-8720-da375be2fa6b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10933806 (10M) [image/jpeg]
# Saving to: ‘training_images/DSC_4339_4e245e6c-c89c-48ce-8720-da375be2fa6b.jpg.1’
#
# DSC_4339_4e245e6c-c 100%[===================>]  10.43M  19.1MB/s    in 0.5s
#
# 2021-07-31 17:14:11 (19.1 MB/s) - ‘training_images/DSC_4339_4e245e6c-c89c-48ce-8720-da375be2fa6b.jpg.1’ saved [10933806/10933806]
#
# --2021-07-31 17:14:11--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_f8a5ebab-c271-418c-bc55-73a4429641d1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8075756 (7.7M) [image/jpeg]
# Saving to: ‘training_images/FEMA_Reg_f8a5ebab-c271-418c-bc55-73a4429641d1.jpg’
#
# FEMA_Reg_f8a5ebab-c 100%[===================>]   7.70M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:11 (72.8 MB/s) - ‘training_images/FEMA_Reg_f8a5ebab-c271-418c-bc55-73a4429641d1.jpg’ saved [8075756/8075756]
#
# --2021-07-31 17:14:11--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8250_b96ffef2-5bf5-4af2-bcd4-8b00b4e99bea.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12965423 (12M) [image/jpeg]
# Saving to: ‘training_images/DSC_8250_b96ffef2-5bf5-4af2-bcd4-8b00b4e99bea.jpg’
#
# DSC_8250_b96ffef2-5 100%[===================>]  12.36M  21.9MB/s    in 0.6s
#
# 2021-07-31 17:14:12 (21.9 MB/s) - ‘training_images/DSC_8250_b96ffef2-5bf5-4af2-bcd4-8b00b4e99bea.jpg’ saved [12965423/12965423]
#
# --2021-07-31 17:14:12--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_3cdc09ad-b4d9-4f34-a42e-002e6fa3da9e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3448898 (3.3M) [image/jpeg]
# Saving to: ‘training_images/SteveBla_3cdc09ad-b4d9-4f34-a42e-002e6fa3da9e.jpg’
#
# SteveBla_3cdc09ad-b 100%[===================>]   3.29M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:12 (32.8 MB/s) - ‘training_images/SteveBla_3cdc09ad-b4d9-4f34-a42e-002e6fa3da9e.jpg’ saved [3448898/3448898]
#
# --2021-07-31 17:14:12--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615474/Dec17201_376ba63c-004e-412a-bdd2-db8dbf7840d6.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5702944 (5.4M) [image/jpeg]
# Saving to: ‘training_images/Dec17201_376ba63c-004e-412a-bdd2-db8dbf7840d6.jpg’
#
# Dec17201_376ba63c-0 100%[===================>]   5.44M  28.8MB/s    in 0.2s
#
# 2021-07-31 17:14:12 (28.8 MB/s) - ‘training_images/Dec17201_376ba63c-004e-412a-bdd2-db8dbf7840d6.jpg’ saved [5702944/5702944]
#
# --2021-07-31 17:14:12--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614044/A0153_AP_ddd52367-ee55-4223-b436-8d3aae345901.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7625761 (7.3M) [image/jpeg]
# Saving to: ‘training_images/A0153_AP_ddd52367-ee55-4223-b436-8d3aae345901.jpg.1’
#
# A0153_AP_ddd52367-e 100%[===================>]   7.27M  32.5MB/s    in 0.2s
#
# 2021-07-31 17:14:13 (32.5 MB/s) - ‘training_images/A0153_AP_ddd52367-ee55-4223-b436-8d3aae345901.jpg.1’ saved [7625761/7625761]
#
# --2021-07-31 17:14:13--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1176_a2378f70-12f6-4427-84d9-9e769e82513e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10670196 (10M) [image/jpeg]
# Saving to: ‘training_images/DSC_1176_a2378f70-12f6-4427-84d9-9e769e82513e.jpg’
#
# DSC_1176_a2378f70-1 100%[===================>]  10.18M  31.9MB/s    in 0.3s
#
# 2021-07-31 17:14:13 (31.9 MB/s) - ‘training_images/DSC_1176_a2378f70-12f6-4427-84d9-9e769e82513e.jpg’ saved [10670196/10670196]
#
# --2021-07-31 17:14:13--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/100502/010_1436_b1b1c434-110f-4743-9193-9684a8e6ebff.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6737914 (6.4M) [image/jpeg]
# Saving to: ‘training_images/010_1436_b1b1c434-110f-4743-9193-9684a8e6ebff.jpg’
#
# 010_1436_b1b1c434-1 100%[===================>]   6.42M  38.2MB/s    in 0.2s
#
# 2021-07-31 17:14:14 (38.2 MB/s) - ‘training_images/010_1436_b1b1c434-110f-4743-9193-9684a8e6ebff.jpg’ saved [6737914/6737914]
#
# --2021-07-31 17:14:14--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614071/A0013_AP_2bb822e9-3638-48db-9286-f4e6826b1a2b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6971823 (6.6M) [image/jpeg]
# Saving to: ‘training_images/A0013_AP_2bb822e9-3638-48db-9286-f4e6826b1a2b.jpg’
#
# A0013_AP_2bb822e9-3 100%[===================>]   6.65M  20.1MB/s    in 0.3s
#
# 2021-07-31 17:14:14 (20.1 MB/s) - ‘training_images/A0013_AP_2bb822e9-3638-48db-9286-f4e6826b1a2b.jpg’ saved [6971823/6971823]
#
# --2021-07-31 17:14:14--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_f39eb09e-f951-4850-8673-cd3644fe6411.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3468394 (3.3M) [image/jpeg]
# Saving to: ‘training_images/SteveBla_f39eb09e-f951-4850-8673-cd3644fe6411.jpg’
#
# SteveBla_f39eb09e-f 100%[===================>]   3.31M  --.-KB/s    in 0.05s
#
# 2021-07-31 17:14:14 (63.1 MB/s) - ‘training_images/SteveBla_f39eb09e-f951-4850-8673-cd3644fe6411.jpg’ saved [3468394/3468394]
#
# --2021-07-31 17:14:14--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291504/DSC_0460_102658f8-ebfd-4c56-8fac-7077abe69f80.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10895090 (10M) [image/jpeg]
# Saving to: ‘training_images/DSC_0460_102658f8-ebfd-4c56-8fac-7077abe69f80.jpg.2’
#
# DSC_0460_102658f8-e 100%[===================>]  10.39M  33.5MB/s    in 0.3s
#
# 2021-07-31 17:14:15 (33.5 MB/s) - ‘training_images/DSC_0460_102658f8-ebfd-4c56-8fac-7077abe69f80.jpg.2’ saved [10895090/10895090]
#
# --2021-07-31 17:14:15--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0099_bfb7defd-84c1-4f90-8319-26a346cff541.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6049198 (5.8M) [image/jpeg]
# Saving to: ‘training_images/DSC_0099_bfb7defd-84c1-4f90-8319-26a346cff541.jpg’
#
# DSC_0099_bfb7defd-8 100%[===================>]   5.77M  29.2MB/s    in 0.2s
#
# 2021-07-31 17:14:15 (29.2 MB/s) - ‘training_images/DSC_0099_bfb7defd-84c1-4f90-8319-26a346cff541.jpg’ saved [6049198/6049198]
#
# --2021-07-31 17:14:15--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613895/DSC_3676_289e6bd9-39bb-42e9-8104-435e219c52d0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11594255 (11M) [image/jpeg]
# Saving to: ‘training_images/DSC_3676_289e6bd9-39bb-42e9-8104-435e219c52d0.jpg’
#
# DSC_3676_289e6bd9-3 100%[===================>]  11.06M  23.8MB/s    in 0.5s
#
# 2021-07-31 17:14:16 (23.8 MB/s) - ‘training_images/DSC_3676_289e6bd9-39bb-42e9-8104-435e219c52d0.jpg’ saved [11594255/11594255]
#
# --2021-07-31 17:14:16--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613883/DSC_0832_16dd745d-7c91-41b7-b42d-bc352b23dfc1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11059706 (11M) [image/jpeg]
# Saving to: ‘training_images/DSC_0832_16dd745d-7c91-41b7-b42d-bc352b23dfc1.jpg’
#
# DSC_0832_16dd745d-7 100%[===================>]  10.55M  20.2MB/s    in 0.5s
#
# 2021-07-31 17:14:17 (20.2 MB/s) - ‘training_images/DSC_0832_16dd745d-7c91-41b7-b42d-bc352b23dfc1.jpg’ saved [11059706/11059706]
#
# --2021-07-31 17:14:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_666f32fd-82e3-4434-996b-bd86b28e300f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3522256 (3.4M) [image/jpeg]
# Saving to: ‘training_images/JoeBell-_666f32fd-82e3-4434-996b-bd86b28e300f.jpg’
#
# JoeBell-_666f32fd-8 100%[===================>]   3.36M  --.-KB/s    in 0.09s
#
# 2021-07-31 17:14:17 (35.8 MB/s) - ‘training_images/JoeBell-_666f32fd-82e3-4434-996b-bd86b28e300f.jpg’ saved [3522256/3522256]
#
# --2021-07-31 17:14:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291611/DSC_0209_f63e9a0c-78d4-4217-ba04-9fb2067f701f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6382353 (6.1M) [image/jpeg]
# Saving to: ‘training_images/DSC_0209_f63e9a0c-78d4-4217-ba04-9fb2067f701f.jpg’
#
# DSC_0209_f63e9a0c-7 100%[===================>]   6.09M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:17 (59.6 MB/s) - ‘training_images/DSC_0209_f63e9a0c-78d4-4217-ba04-9fb2067f701f.jpg’ saved [6382353/6382353]
#
# --2021-07-31 17:14:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614107/A0025_AP_fa2b6899-c5b0-4ab5-891e-2035195bed5b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7644654 (7.3M) [image/jpeg]
# Saving to: ‘training_images/A0025_AP_fa2b6899-c5b0-4ab5-891e-2035195bed5b.jpg’
#
# A0025_AP_fa2b6899-c 100%[===================>]   7.29M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:17 (60.9 MB/s) - ‘training_images/A0025_AP_fa2b6899-c5b0-4ab5-891e-2035195bed5b.jpg’ saved [7644654/7644654]
#
# --2021-07-31 17:14:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616222/FEMA_REG_01e676f0-40f2-4d21-8bf2-3a2680af6414.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5184886 (4.9M) [image/jpeg]
# Saving to: ‘training_images/FEMA_REG_01e676f0-40f2-4d21-8bf2-3a2680af6414.jpg’
#
# FEMA_REG_01e676f0-4 100%[===================>]   4.94M  20.2MB/s    in 0.2s
#
# 2021-07-31 17:14:18 (20.2 MB/s) - ‘training_images/FEMA_REG_01e676f0-40f2-4d21-8bf2-3a2680af6414.jpg’ saved [5184886/5184886]
#
# --2021-07-31 17:14:18--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/613986/A0046V-0_19b372c0-9a9e-4572-ad4a-ea2fdeab4cc0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3509279 (3.3M) [image/jpeg]
# Saving to: ‘training_images/A0046V-0_19b372c0-9a9e-4572-ad4a-ea2fdeab4cc0.jpg’
#
# A0046V-0_19b372c0-9 100%[===================>]   3.35M  --.-KB/s    in 0.08s
#
# 2021-07-31 17:14:18 (40.3 MB/s) - ‘training_images/A0046V-0_19b372c0-9a9e-4572-ad4a-ea2fdeab4cc0.jpg’ saved [3509279/3509279]
#
# --2021-07-31 17:14:18--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613895/DSC_6275_a025f7e6-b353-4b90-9c2b-6e08f1022ca5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10970643 (10M) [image/jpeg]
# Saving to: ‘training_images/DSC_6275_a025f7e6-b353-4b90-9c2b-6e08f1022ca5.jpg’
#
# DSC_6275_a025f7e6-b 100%[===================>]  10.46M  18.0MB/s    in 0.6s
#
# 2021-07-31 17:14:19 (18.0 MB/s) - ‘training_images/DSC_6275_a025f7e6-b353-4b90-9c2b-6e08f1022ca5.jpg’ saved [10970643/10970643]
#
# --2021-07-31 17:14:19--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614110/A0068_AP_254853fc-69ba-44ad-b83c-7baa35f6d339.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7376232 (7.0M) [image/jpeg]
# Saving to: ‘training_images/A0068_AP_254853fc-69ba-44ad-b83c-7baa35f6d339.jpg’
#
# A0068_AP_254853fc-6 100%[===================>]   7.03M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:19 (69.3 MB/s) - ‘training_images/A0068_AP_254853fc-69ba-44ad-b83c-7baa35f6d339.jpg’ saved [7376232/7376232]
#
# --2021-07-31 17:14:19--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613865/DSC_1508_8eb52d14-71ea-4c1d-820a-79b8d4036e01.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12238916 (12M) [image/jpeg]
# Saving to: ‘training_images/DSC_1508_8eb52d14-71ea-4c1d-820a-79b8d4036e01.jpg’
#
# DSC_1508_8eb52d14-7 100%[===================>]  11.67M  38.0MB/s    in 0.3s
#
# 2021-07-31 17:14:20 (38.0 MB/s) - ‘training_images/DSC_1508_8eb52d14-71ea-4c1d-820a-79b8d4036e01.jpg’ saved [12238916/12238916]
#
# --2021-07-31 17:14:20--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_701797fa-802f-45b2-90c8-47ef172b52b7.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3503220 (3.3M) [image/jpeg]
# Saving to: ‘training_images/SteveBla_701797fa-802f-45b2-90c8-47ef172b52b7.jpg.1’
#
# SteveBla_701797fa-8 100%[===================>]   3.34M  14.0MB/s    in 0.2s
#
# 2021-07-31 17:14:20 (14.0 MB/s) - ‘training_images/SteveBla_701797fa-802f-45b2-90c8-47ef172b52b7.jpg.1’ saved [3503220/3503220]
#
# --2021-07-31 17:14:20--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_494b255e-9992-46fc-b245-f661fb47f003.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3483761 (3.3M) [image/jpeg]
# Saving to: ‘training_images/SteveBla_494b255e-9992-46fc-b245-f661fb47f003.jpg’
#
# SteveBla_494b255e-9 100%[===================>]   3.32M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:20 (29.0 MB/s) - ‘training_images/SteveBla_494b255e-9992-46fc-b245-f661fb47f003.jpg’ saved [3483761/3483761]
#
# --2021-07-31 17:14:20--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_f828d6f5-1cf3-48aa-81ab-947f81deafbc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4341286 (4.1M) [image/jpeg]
# Saving to: ‘training_images/DavidBen_f828d6f5-1cf3-48aa-81ab-947f81deafbc.jpg’
#
# DavidBen_f828d6f5-1 100%[===================>]   4.14M  --.-KB/s    in 0.05s
#
# 2021-07-31 17:14:21 (79.4 MB/s) - ‘training_images/DavidBen_f828d6f5-1cf3-48aa-81ab-947f81deafbc.jpg’ saved [4341286/4341286]
#
# --2021-07-31 17:14:21--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_667610b5-9448-4dad-8a5c-094d1d4ff730.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9363828 (8.9M) [image/jpeg]
# Saving to: ‘training_images/FEMA_Reg_667610b5-9448-4dad-8a5c-094d1d4ff730.jpg’
#
# FEMA_Reg_667610b5-9 100%[===================>]   8.93M  28.9MB/s    in 0.3s
#
# 2021-07-31 17:14:21 (28.9 MB/s) - ‘training_images/FEMA_Reg_667610b5-9448-4dad-8a5c-094d1d4ff730.jpg’ saved [9363828/9363828]
#
# --2021-07-31 17:14:21--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616226/FEMA_Reg_596399f7-6e6a-4b86-9c83-af41995a39f5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3127433 (3.0M) [image/jpeg]
# Saving to: ‘training_images/FEMA_Reg_596399f7-6e6a-4b86-9c83-af41995a39f5.jpg’
#
# FEMA_Reg_596399f7-6 100%[===================>]   2.98M  --.-KB/s    in 0.05s
#
# 2021-07-31 17:14:21 (61.2 MB/s) - ‘training_images/FEMA_Reg_596399f7-6e6a-4b86-9c83-af41995a39f5.jpg’ saved [3127433/3127433]
#
# --2021-07-31 17:14:21--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616209/DSC_0152_b9b09f7a-6654-4960-8dce-0d92438fcc53.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11283037 (11M) [image/jpeg]
# Saving to: ‘training_images/DSC_0152_b9b09f7a-6654-4960-8dce-0d92438fcc53.jpg’
#
# DSC_0152_b9b09f7a-6 100%[===================>]  10.76M  19.2MB/s    in 0.6s
#
# 2021-07-31 17:14:22 (19.2 MB/s) - ‘training_images/DSC_0152_b9b09f7a-6654-4960-8dce-0d92438fcc53.jpg’ saved [11283037/11283037]
#
# --2021-07-31 17:14:22--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615123/ChrisPet_b6e28ec1-2e16-478e-a9a4-50bc395eaf5f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3454412 (3.3M) [image/jpeg]
# Saving to: ‘training_images/ChrisPet_b6e28ec1-2e16-478e-a9a4-50bc395eaf5f.jpg’
#
# ChrisPet_b6e28ec1-2 100%[===================>]   3.29M  20.6MB/s    in 0.2s
#
# 2021-07-31 17:14:22 (20.6 MB/s) - ‘training_images/ChrisPet_b6e28ec1-2e16-478e-a9a4-50bc395eaf5f.jpg’ saved [3454412/3454412]
#
# --2021-07-31 17:14:22--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8004_8962ae7e-5af8-44d0-b594-850851ed480e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13019902 (12M) [image/jpeg]
# Saving to: ‘training_images/DSC_8004_8962ae7e-5af8-44d0-b594-850851ed480e.jpg’
#
# DSC_8004_8962ae7e-5 100%[===================>]  12.42M  29.4MB/s    in 0.4s
#
# 2021-07-31 17:14:23 (29.4 MB/s) - ‘training_images/DSC_8004_8962ae7e-5af8-44d0-b594-850851ed480e.jpg’ saved [13019902/13019902]
#
# --2021-07-31 17:14:23--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_3e0c73f8-a016-4805-bf5d-8b73a27b74f1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6009954 (5.7M) [image/jpeg]
# Saving to: ‘training_images/DavidBen_3e0c73f8-a016-4805-bf5d-8b73a27b74f1.jpg’
#
# DavidBen_3e0c73f8-a 100%[===================>]   5.73M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:23 (42.3 MB/s) - ‘training_images/DavidBen_3e0c73f8-a016-4805-bf5d-8b73a27b74f1.jpg’ saved [6009954/6009954]
#
# --2021-07-31 17:14:23--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613883/DSC_1246_cf2da2c4-856d-4015-a1f8-7cc26ea2c211.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11717884 (11M) [image/jpeg]
# Saving to: ‘training_images/DSC_1246_cf2da2c4-856d-4015-a1f8-7cc26ea2c211.jpg’
#
# DSC_1246_cf2da2c4-8 100%[===================>]  11.17M  28.7MB/s    in 0.4s
#
# 2021-07-31 17:14:24 (28.7 MB/s) - ‘training_images/DSC_1246_cf2da2c4-856d-4015-a1f8-7cc26ea2c211.jpg’ saved [11717884/11717884]
#
# --2021-07-31 17:14:24--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613735/DSC_0044_0dd6aaab-055a-4063-af92-85db7575c0b2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6073107 (5.8M) [image/jpeg]
# Saving to: ‘training_images/DSC_0044_0dd6aaab-055a-4063-af92-85db7575c0b2.jpg’
#
# DSC_0044_0dd6aaab-0 100%[===================>]   5.79M  32.3MB/s    in 0.2s
#
# 2021-07-31 17:14:24 (32.3 MB/s) - ‘training_images/DSC_0044_0dd6aaab-055a-4063-af92-85db7575c0b2.jpg’ saved [6073107/6073107]
#
# --2021-07-31 17:14:24--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614172/A0083_AP_c70bfb39-c696-467f-a515-bf0f604cee40.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5975349 (5.7M) [image/jpeg]
# Saving to: ‘training_images/A0083_AP_c70bfb39-c696-467f-a515-bf0f604cee40.jpg’
#
# A0083_AP_c70bfb39-c 100%[===================>]   5.70M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:25 (55.6 MB/s) - ‘training_images/A0083_AP_c70bfb39-c696-467f-a515-bf0f604cee40.jpg’ saved [5975349/5975349]
#
# --2021-07-31 17:14:25--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614089/A0074_AP_f8949a65-5144-4214-8b7b-e673e22e0acb.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7831923 (7.5M) [image/jpeg]
# Saving to: ‘training_images/A0074_AP_f8949a65-5144-4214-8b7b-e673e22e0acb.jpg’
#
# A0074_AP_f8949a65-5 100%[===================>]   7.47M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:25 (52.3 MB/s) - ‘training_images/A0074_AP_f8949a65-5144-4214-8b7b-e673e22e0acb.jpg’ saved [7831923/7831923]
#
# --2021-07-31 17:14:25--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613946/DSC_6416_ed5642cf-d854-47ad-a120-b9bd81e7facf.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10415553 (9.9M) [image/jpeg]
# Saving to: ‘training_images/DSC_6416_ed5642cf-d854-47ad-a120-b9bd81e7facf.jpg’
#
# DSC_6416_ed5642cf-d 100%[===================>]   9.93M  64.4MB/s    in 0.2s
#
# 2021-07-31 17:14:25 (64.4 MB/s) - ‘training_images/DSC_6416_ed5642cf-d854-47ad-a120-b9bd81e7facf.jpg’ saved [10415553/10415553]
#
# --2021-07-31 17:14:25--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_f159858b-ca7e-4d0c-92ef-34cb21f71a62.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3487812 (3.3M) [image/jpeg]
# Saving to: ‘training_images/BrettGro_f159858b-ca7e-4d0c-92ef-34cb21f71a62.jpg’
#
# BrettGro_f159858b-c 100%[===================>]   3.33M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:25 (25.2 MB/s) - ‘training_images/BrettGro_f159858b-ca7e-4d0c-92ef-34cb21f71a62.jpg’ saved [3487812/3487812]
#
# --2021-07-31 17:14:25--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_7c70d0dd-e54b-4ee6-bec8-a1610a551bc0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4875774 (4.6M) [image/jpeg]
# Saving to: ‘training_images/TimCooli_7c70d0dd-e54b-4ee6-bec8-a1610a551bc0.jpg’
#
# TimCooli_7c70d0dd-e 100%[===================>]   4.65M  24.5MB/s    in 0.2s
#
# 2021-07-31 17:14:26 (24.5 MB/s) - ‘training_images/TimCooli_7c70d0dd-e54b-4ee6-bec8-a1610a551bc0.jpg’ saved [4875774/4875774]
#
# --2021-07-31 17:14:26--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615224/Bay-Gulf_19349b39-905d-4827-94ff-1214c1ff6683.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14050633 (13M) [image/jpeg]
# Saving to: ‘training_images/Bay-Gulf_19349b39-905d-4827-94ff-1214c1ff6683.jpg’
#
# Bay-Gulf_19349b39-9 100%[===================>]  13.40M  24.7MB/s    in 0.5s
#
# 2021-07-31 17:14:26 (24.7 MB/s) - ‘training_images/Bay-Gulf_19349b39-905d-4827-94ff-1214c1ff6683.jpg’ saved [14050633/14050633]
#
# --2021-07-31 17:14:26--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616210/DSC_0981_1a25fd14-f09e-48cc-a6e9-491466e9db7d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15398919 (15M) [image/jpeg]
# Saving to: ‘training_images/DSC_0981_1a25fd14-f09e-48cc-a6e9-491466e9db7d.jpg’
#
# DSC_0981_1a25fd14-f 100%[===================>]  14.69M  23.9MB/s    in 0.6s
#
# 2021-07-31 17:14:27 (23.9 MB/s) - ‘training_images/DSC_0981_1a25fd14-f09e-48cc-a6e9-491466e9db7d.jpg’ saved [15398919/15398919]
#
# --2021-07-31 17:14:27--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_e0f756a5-8fae-47b0-98f6-2fa816c2a656.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5596324 (5.3M) [image/jpeg]
# Saving to: ‘training_images/DavidBen_e0f756a5-8fae-47b0-98f6-2fa816c2a656.jpg’
#
# DavidBen_e0f756a5-8 100%[===================>]   5.34M  35.5MB/s    in 0.2s
#
# 2021-07-31 17:14:28 (35.5 MB/s) - ‘training_images/DavidBen_e0f756a5-8fae-47b0-98f6-2fa816c2a656.jpg’ saved [5596324/5596324]
#
# --2021-07-31 17:14:28--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615035/DSC_0069_4e7cbfbb-522e-4228-bc06-313e11f38d25.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10016665 (9.6M) [image/jpeg]
# Saving to: ‘training_images/DSC_0069_4e7cbfbb-522e-4228-bc06-313e11f38d25.jpg’
#
# DSC_0069_4e7cbfbb-5 100%[===================>]   9.55M  30.7MB/s    in 0.3s
#
# 2021-07-31 17:14:28 (30.7 MB/s) - ‘training_images/DSC_0069_4e7cbfbb-522e-4228-bc06-313e11f38d25.jpg’ saved [10016665/10016665]
#
# --2021-07-31 17:14:28--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_163a3a48-a4ea-4b3b-a090-f9cb7b1c563b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5112291 (4.9M) [image/jpeg]
# Saving to: ‘training_images/FEMA_REG_163a3a48-a4ea-4b3b-a090-f9cb7b1c563b.jpg’
#
# FEMA_REG_163a3a48-a 100%[===================>]   4.88M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:28 (38.7 MB/s) - ‘training_images/FEMA_REG_163a3a48-a4ea-4b3b-a090-f9cb7b1c563b.jpg’ saved [5112291/5112291]
#
# --2021-07-31 17:14:28--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_ba2ef4e4-4c5d-4b44-a747-3cf560dc3001.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3506947 (3.3M) [image/jpeg]
# Saving to: ‘training_images/JoeBell-_ba2ef4e4-4c5d-4b44-a747-3cf560dc3001.jpg’
#
# JoeBell-_ba2ef4e4-4 100%[===================>]   3.34M  --.-KB/s    in 0.05s
#
# 2021-07-31 17:14:28 (66.2 MB/s) - ‘training_images/JoeBell-_ba2ef4e4-4c5d-4b44-a747-3cf560dc3001.jpg’ saved [3506947/3506947]
#
# --2021-07-31 17:14:28--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_094996ad-eca2-4d46-abb7-06c9a780da8d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3559862 (3.4M) [image/jpeg]
# Saving to: ‘training_images/JoeBell-_094996ad-eca2-4d46-abb7-06c9a780da8d.jpg.1’
#
# JoeBell-_094996ad-e 100%[===================>]   3.39M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:29 (28.7 MB/s) - ‘training_images/JoeBell-_094996ad-eca2-4d46-abb7-06c9a780da8d.jpg.1’ saved [3559862/3559862]
#
# --2021-07-31 17:14:29--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0199_da68db48-698c-45dd-86a0-2a032c27fe5f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3485331 (3.3M) [image/jpeg]
# Saving to: ‘training_images/VIRB0199_da68db48-698c-45dd-86a0-2a032c27fe5f.jpg.1’
#
# VIRB0199_da68db48-6 100%[===================>]   3.32M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:29 (23.7 MB/s) - ‘training_images/VIRB0199_da68db48-698c-45dd-86a0-2a032c27fe5f.jpg.1’ saved [3485331/3485331]
#
# --2021-07-31 17:14:29--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614109/DSC_0721_14535827-5ae2-4bd4-a6d0-07bb47c586ac.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7802213 (7.4M) [image/jpeg]
# Saving to: ‘training_images/DSC_0721_14535827-5ae2-4bd4-a6d0-07bb47c586ac.jpg’
#
# DSC_0721_14535827-5 100%[===================>]   7.44M  31.9MB/s    in 0.2s
#
# 2021-07-31 17:14:29 (31.9 MB/s) - ‘training_images/DSC_0721_14535827-5ae2-4bd4-a6d0-07bb47c586ac.jpg’ saved [7802213/7802213]
#
# --2021-07-31 17:14:29--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614090/A0088_AP_40a028d0-85a5-4767-aa9d-17d47ead5ed5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7700589 (7.3M) [image/jpeg]
# Saving to: ‘training_images/A0088_AP_40a028d0-85a5-4767-aa9d-17d47ead5ed5.jpg’
#
# A0088_AP_40a028d0-8 100%[===================>]   7.34M  47.4MB/s    in 0.2s
#
# 2021-07-31 17:14:30 (47.4 MB/s) - ‘training_images/A0088_AP_40a028d0-85a5-4767-aa9d-17d47ead5ed5.jpg’ saved [7700589/7700589]
#
# --2021-07-31 17:14:30--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2667_a8b2aa8b-de74-432b-a8d4-3c33f6a513c7.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10292070 (9.8M) [image/jpeg]
# Saving to: ‘training_images/DSC_2667_a8b2aa8b-de74-432b-a8d4-3c33f6a513c7.jpg.1’
#
# DSC_2667_a8b2aa8b-d 100%[===================>]   9.81M  37.8MB/s    in 0.3s
#
# 2021-07-31 17:14:30 (37.8 MB/s) - ‘training_images/DSC_2667_a8b2aa8b-de74-432b-a8d4-3c33f6a513c7.jpg.1’ saved [10292070/10292070]
#
# --2021-07-31 17:14:30--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0152_5bee4a74-3f3c-4125-a434-0a4c378c42dd.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3523218 (3.4M) [image/jpeg]
# Saving to: ‘training_images/VIRB0152_5bee4a74-3f3c-4125-a434-0a4c378c42dd.jpg.2’
#
# VIRB0152_5bee4a74-3 100%[===================>]   3.36M  11.5MB/s    in 0.3s
#
# 2021-07-31 17:14:31 (11.5 MB/s) - ‘training_images/VIRB0152_5bee4a74-3f3c-4125-a434-0a4c378c42dd.jpg.2’ saved [3523218/3523218]
#
# --2021-07-31 17:14:31--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614029/A0070_AP_3a5efedf-7e14-4f38-abf2-2e96c5fd2f45.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7606097 (7.3M) [image/jpeg]
# Saving to: ‘training_images/A0070_AP_3a5efedf-7e14-4f38-abf2-2e96c5fd2f45.jpg’
#
# A0070_AP_3a5efedf-7 100%[===================>]   7.25M  20.3MB/s    in 0.4s
#
# 2021-07-31 17:14:31 (20.3 MB/s) - ‘training_images/A0070_AP_3a5efedf-7e14-4f38-abf2-2e96c5fd2f45.jpg’ saved [7606097/7606097]
#
# --2021-07-31 17:14:31--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614003/A0027V01_10282c0e-49a1-4880-b38c-3534a7238d9a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3447522 (3.3M) [image/jpeg]
# Saving to: ‘training_images/A0027V01_10282c0e-49a1-4880-b38c-3534a7238d9a.jpg’
#
# A0027V01_10282c0e-4 100%[===================>]   3.29M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:31 (25.6 MB/s) - ‘training_images/A0027V01_10282c0e-49a1-4880-b38c-3534a7238d9a.jpg’ saved [3447522/3447522]
#
# --2021-07-31 17:14:31--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614004/A0019044_4d10e2a6-9bbc-4139-a5c5-bfb6f7730731.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3454927 (3.3M) [image/jpeg]
# Saving to: ‘training_images/A0019044_4d10e2a6-9bbc-4139-a5c5-bfb6f7730731.jpg’
#
# A0019044_4d10e2a6-9 100%[===================>]   3.29M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:32 (24.0 MB/s) - ‘training_images/A0019044_4d10e2a6-9bbc-4139-a5c5-bfb6f7730731.jpg’ saved [3454927/3454927]
#
# --2021-07-31 17:14:32--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615483/DSC_1270_72665f67-d503-48ea-b173-fa018a1d2f5a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15988485 (15M) [image/jpeg]
# Saving to: ‘training_images/DSC_1270_72665f67-d503-48ea-b173-fa018a1d2f5a.jpg’
#
# DSC_1270_72665f67-d 100%[===================>]  15.25M  33.8MB/s    in 0.5s
#
# 2021-07-31 17:14:32 (33.8 MB/s) - ‘training_images/DSC_1270_72665f67-d503-48ea-b173-fa018a1d2f5a.jpg’ saved [15988485/15988485]
#
# --2021-07-31 17:14:32--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614003/A0027V01_512e380f-4a41-4d4a-a149-b40711bade55.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3461629 (3.3M) [image/jpeg]
# Saving to: ‘training_images/A0027V01_512e380f-4a41-4d4a-a149-b40711bade55.jpg’
#
# A0027V01_512e380f-4 100%[===================>]   3.30M  --.-KB/s    in 0.07s
#
# 2021-07-31 17:14:33 (46.2 MB/s) - ‘training_images/A0027V01_512e380f-4a41-4d4a-a149-b40711bade55.jpg’ saved [3461629/3461629]
#
# --2021-07-31 17:14:33--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20253/DSC_0057_c2a900f2-998a-4dd8-a356-e5776b38ff66.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6292029 (6.0M) [image/jpeg]
# Saving to: ‘training_images/DSC_0057_c2a900f2-998a-4dd8-a356-e5776b38ff66.jpg’
#
# DSC_0057_c2a900f2-9 100%[===================>]   6.00M  32.8MB/s    in 0.2s
#
# 2021-07-31 17:14:33 (32.8 MB/s) - ‘training_images/DSC_0057_c2a900f2-998a-4dd8-a356-e5776b38ff66.jpg’ saved [6292029/6292029]
#
# --2021-07-31 17:14:33--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8222_96a21aa2-3c63-43f8-876e-63bdc06c9064.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16463887 (16M) [image/jpeg]
# Saving to: ‘training_images/DSC_8222_96a21aa2-3c63-43f8-876e-63bdc06c9064.jpg’
#
# DSC_8222_96a21aa2-3 100%[===================>]  15.70M  35.5MB/s    in 0.4s
#
# 2021-07-31 17:14:34 (35.5 MB/s) - ‘training_images/DSC_8222_96a21aa2-3c63-43f8-876e-63bdc06c9064.jpg’ saved [16463887/16463887]
#
# --2021-07-31 17:14:34--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7987_8ab87da9-cd8e-4ceb-8459-ac5beb4ea439.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16008225 (15M) [image/jpeg]
# Saving to: ‘training_images/DSC_7987_8ab87da9-cd8e-4ceb-8459-ac5beb4ea439.jpg’
#
# DSC_7987_8ab87da9-c 100%[===================>]  15.27M  29.3MB/s    in 0.5s
#
# 2021-07-31 17:14:34 (29.3 MB/s) - ‘training_images/DSC_7987_8ab87da9-cd8e-4ceb-8459-ac5beb4ea439.jpg’ saved [16008225/16008225]
#
# --2021-07-31 17:14:34--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_fd5e0941-b608-47bc-af4c-fc313efec97a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3507245 (3.3M) [image/jpeg]
# Saving to: ‘training_images/JoeBell-_fd5e0941-b608-47bc-af4c-fc313efec97a.jpg’
#
# JoeBell-_fd5e0941-b 100%[===================>]   3.34M  20.8MB/s    in 0.2s
#
# 2021-07-31 17:14:35 (20.8 MB/s) - ‘training_images/JoeBell-_fd5e0941-b608-47bc-af4c-fc313efec97a.jpg’ saved [3507245/3507245]
#
# --2021-07-31 17:14:35--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615223/VIRB0172_c9910c76-5a46-48b6-a86b-06be4cbb7a8e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3548185 (3.4M) [image/jpeg]
# Saving to: ‘training_images/VIRB0172_c9910c76-5a46-48b6-a86b-06be4cbb7a8e.jpg’
#
# VIRB0172_c9910c76-5 100%[===================>]   3.38M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:35 (30.3 MB/s) - ‘training_images/VIRB0172_c9910c76-5a46-48b6-a86b-06be4cbb7a8e.jpg’ saved [3548185/3548185]
#
# --2021-07-31 17:14:35--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_3efbcd5b-a7fc-47ae-846b-f3e0c644c390.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3512884 (3.3M) [image/jpeg]
# Saving to: ‘training_images/JoeBell-_3efbcd5b-a7fc-47ae-846b-f3e0c644c390.jpg’
#
# JoeBell-_3efbcd5b-a 100%[===================>]   3.35M  --.-KB/s    in 0.08s
#
# 2021-07-31 17:14:35 (40.9 MB/s) - ‘training_images/JoeBell-_3efbcd5b-a7fc-47ae-846b-f3e0c644c390.jpg’ saved [3512884/3512884]
#
# --2021-07-31 17:14:35--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_6cefacc0-9a4b-4599-9b43-48ea4816e870.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4661011 (4.4M) [image/jpeg]
# Saving to: ‘training_images/DavidBen_6cefacc0-9a4b-4599-9b43-48ea4816e870.jpg’
#
# DavidBen_6cefacc0-9 100%[===================>]   4.44M  29.1MB/s    in 0.2s
#
# 2021-07-31 17:14:35 (29.1 MB/s) - ‘training_images/DavidBen_6cefacc0-9a4b-4599-9b43-48ea4816e870.jpg’ saved [4661011/4661011]
#
# --2021-07-31 17:14:35--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614104/A0084_AP_760c424a-816f-4aa3-9a99-2454fd141eae.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7665121 (7.3M) [image/jpeg]
# Saving to: ‘training_images/A0084_AP_760c424a-816f-4aa3-9a99-2454fd141eae.jpg’
#
# A0084_AP_760c424a-8 100%[===================>]   7.31M  38.9MB/s    in 0.2s
#
# 2021-07-31 17:14:36 (38.9 MB/s) - ‘training_images/A0084_AP_760c424a-816f-4aa3-9a99-2454fd141eae.jpg’ saved [7665121/7665121]
#
# --2021-07-31 17:14:36--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_a4099275-d4b7-41bb-9109-edc3440ed3c4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9283395 (8.9M) [image/jpeg]
# Saving to: ‘training_images/FEMA_Reg_a4099275-d4b7-41bb-9109-edc3440ed3c4.jpg’
#
# FEMA_Reg_a4099275-d 100%[===================>]   8.85M  31.0MB/s    in 0.3s
#
# 2021-07-31 17:14:36 (31.0 MB/s) - ‘training_images/FEMA_Reg_a4099275-d4b7-41bb-9109-edc3440ed3c4.jpg’ saved [9283395/9283395]
#
# --2021-07-31 17:14:36--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8031_88f2c9e2-f5de-4614-87fa-a2421bd1b9c9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14132504 (13M) [image/jpeg]
# Saving to: ‘training_images/DSC_8031_88f2c9e2-f5de-4614-87fa-a2421bd1b9c9.jpg’
#
# DSC_8031_88f2c9e2-f 100%[===================>]  13.48M  55.2MB/s    in 0.2s
#
# 2021-07-31 17:14:37 (55.2 MB/s) - ‘training_images/DSC_8031_88f2c9e2-f5de-4614-87fa-a2421bd1b9c9.jpg’ saved [14132504/14132504]
#
# --2021-07-31 17:14:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_6bd65e6a-5ad5-4517-9940-99f3f008d609.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6342896 (6.0M) [image/jpeg]
# Saving to: ‘training_images/TimCooli_6bd65e6a-5ad5-4517-9940-99f3f008d609.jpg’
#
# TimCooli_6bd65e6a-5 100%[===================>]   6.05M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:37 (61.0 MB/s) - ‘training_images/TimCooli_6bd65e6a-5ad5-4517-9940-99f3f008d609.jpg’ saved [6342896/6342896]
#
# --2021-07-31 17:14:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615122/FLO_1263_ce631cfa-5a58-468c-9e06-35a05b0d2a4c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6151405 (5.9M) [image/jpeg]
# Saving to: ‘training_images/FLO_1263_ce631cfa-5a58-468c-9e06-35a05b0d2a4c.jpg’
#
# FLO_1263_ce631cfa-5 100%[===================>]   5.87M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:37 (42.2 MB/s) - ‘training_images/FLO_1263_ce631cfa-5a58-468c-9e06-35a05b0d2a4c.jpg’ saved [6151405/6151405]
#
# --2021-07-31 17:14:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0150_ead1b3d3-bb94-46b2-9965-62d77022db1f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3517912 (3.4M) [image/jpeg]
# Saving to: ‘training_images/VIRB0150_ead1b3d3-bb94-46b2-9965-62d77022db1f.jpg’
#
# VIRB0150_ead1b3d3-b 100%[===================>]   3.35M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:38 (24.7 MB/s) - ‘training_images/VIRB0150_ead1b3d3-bb94-46b2-9965-62d77022db1f.jpg’ saved [3517912/3517912]
#
# --2021-07-31 17:14:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7963_3cb3f628-c397-442a-be05-df8a5d571186.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15915315 (15M) [image/jpeg]
# Saving to: ‘training_images/DSC_7963_3cb3f628-c397-442a-be05-df8a5d571186.jpg’
#
# DSC_7963_3cb3f628-c 100%[===================>]  15.18M  25.6MB/s    in 0.6s
#
# 2021-07-31 17:14:38 (25.6 MB/s) - ‘training_images/DSC_7963_3cb3f628-c397-442a-be05-df8a5d571186.jpg’ saved [15915315/15915315]
#
# --2021-07-31 17:14:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613741/DSC_4421_86a388e5-07cc-4173-b1e4-ba096f56ddfb.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12756626 (12M) [image/jpeg]
# Saving to: ‘training_images/DSC_4421_86a388e5-07cc-4173-b1e4-ba096f56ddfb.jpg’
#
# DSC_4421_86a388e5-0 100%[===================>]  12.17M  34.8MB/s    in 0.3s
#
# 2021-07-31 17:14:39 (34.8 MB/s) - ‘training_images/DSC_4421_86a388e5-07cc-4173-b1e4-ba096f56ddfb.jpg’ saved [12756626/12756626]
#
# --2021-07-31 17:14:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8174_a7d533b8-df29-4bd0-87e5-413c29858f73.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10570056 (10M) [image/jpeg]
# Saving to: ‘training_images/DSC_8174_a7d533b8-df29-4bd0-87e5-413c29858f73.jpg’
#
# DSC_8174_a7d533b8-d 100%[===================>]  10.08M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:14:39 (67.5 MB/s) - ‘training_images/DSC_8174_a7d533b8-df29-4bd0-87e5-413c29858f73.jpg’ saved [10570056/10570056]
#
# --2021-07-31 17:14:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615067/DSC_3807_57f42f69-7afb-4d63-b2ea-f366cd3293d5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7225573 (6.9M) [image/jpeg]
# Saving to: ‘training_images/DSC_3807_57f42f69-7afb-4d63-b2ea-f366cd3293d5.jpg’
#
# DSC_3807_57f42f69-7 100%[===================>]   6.89M  25.1MB/s    in 0.3s
#
# 2021-07-31 17:14:40 (25.1 MB/s) - ‘training_images/DSC_3807_57f42f69-7afb-4d63-b2ea-f366cd3293d5.jpg’ saved [7225573/7225573]
#
# ...
#
# SteveBla_363af209-e 100%[===================>]   3.34M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:08 (32.6 MB/s) - ‘training_images/SteveBla_363af209-e436-4102-8c16-0a6a8060cb03.jpg.1’ saved [3504124/3504124]
#
# --2021-07-31 17:42:08--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_2316_3279cf90-5ae7-47cf-9cc7-3ed009ff36c9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7317871 (7.0M) [image/jpeg]
# Saving to: ‘training_images/DSC_2316_3279cf90-5ae7-47cf-9cc7-3ed009ff36c9.jpg’
#
# DSC_2316_3279cf90-5 100%[===================>]   6.98M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:08 (69.4 MB/s) - ‘training_images/DSC_2316_3279cf90-5ae7-47cf-9cc7-3ed009ff36c9.jpg’ saved [7317871/7317871]
#
# --2021-07-31 17:42:08--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613808/DSC_9940e3b51c24-8296-4dd1-943e-d9863d162c3f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13515829 (13M) [image/jpeg]
# Saving to: ‘training_images/DSC_9940e3b51c24-8296-4dd1-943e-d9863d162c3f.jpg’
#
# DSC_9940e3b51c24-82 100%[===================>]  12.89M  43.2MB/s    in 0.3s
#
# 2021-07-31 17:42:09 (43.2 MB/s) - ‘training_images/DSC_9940e3b51c24-8296-4dd1-943e-d9863d162c3f.jpg’ saved [13515829/13515829]
#
# --2021-07-31 17:42:09--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8266_6d0583d9-0742-4237-a9dd-1e24f3e4b660.jpg
# Connecting to ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)|52.218.224.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14642300 (14M) [image/jpeg]
# Saving to: ‘training_images/DSC_8266_6d0583d9-0742-4237-a9dd-1e24f3e4b660.jpg’
#
# DSC_8266_6d0583d9-0 100%[===================>]  13.96M  21.1MB/s    in 0.7s
#
# 2021-07-31 17:42:10 (21.1 MB/s) - ‘training_images/DSC_8266_6d0583d9-0742-4237-a9dd-1e24f3e4b660.jpg’ saved [14642300/14642300]
#
# --2021-07-31 17:42:10--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614063/A0086_AP_fca51100-3c41-4fe0-97c0-7edfe5b8d52c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9756519 (9.3M) [image/jpeg]
# Saving to: ‘training_images/A0086_AP_fca51100-3c41-4fe0-97c0-7edfe5b8d52c.jpg’
#
# A0086_AP_fca51100-3 100%[===================>]   9.30M  42.9MB/s    in 0.2s
#
# 2021-07-31 17:42:10 (42.9 MB/s) - ‘training_images/A0086_AP_fca51100-3c41-4fe0-97c0-7edfe5b8d52c.jpg’ saved [9756519/9756519]
#
# --2021-07-31 17:42:10--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615122/FLO_1297_231738f0-11c4-4717-a501-f1fbe603ebf5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5979377 (5.7M) [image/jpeg]
# Saving to: ‘training_images/FLO_1297_231738f0-11c4-4717-a501-f1fbe603ebf5.jpg’
#
# FLO_1297_231738f0-1 100%[===================>]   5.70M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:10 (52.4 MB/s) - ‘training_images/FLO_1297_231738f0-11c4-4717-a501-f1fbe603ebf5.jpg’ saved [5979377/5979377]
#
# --2021-07-31 17:42:10--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_2304_ab44911f-0854-4981-8a02-929df4037858.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7201544 (6.9M) [image/jpeg]
# Saving to: ‘training_images/DSC_2304_ab44911f-0854-4981-8a02-929df4037858.jpg’
#
# DSC_2304_ab44911f-0 100%[===================>]   6.87M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:11 (68.6 MB/s) - ‘training_images/DSC_2304_ab44911f-0854-4981-8a02-929df4037858.jpg’ saved [7201544/7201544]
#
# --2021-07-31 17:42:11--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614004/A0019045_817f9c74-ab6d-432d-b1a3-bae91d81f3fe.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3845638 (3.7M) [image/jpeg]
# Saving to: ‘training_images/A0019045_817f9c74-ab6d-432d-b1a3-bae91d81f3fe.jpg’
#
# A0019045_817f9c74-a 100%[===================>]   3.67M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:11 (28.5 MB/s) - ‘training_images/A0019045_817f9c74-ab6d-432d-b1a3-bae91d81f3fe.jpg’ saved [3845638/3845638]
#
# --2021-07-31 17:42:11--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613926/DSC_3123.JPG
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12044092 (11M) [image/jpeg]
# Saving to: ‘training_images/DSC_3123.JPG’
#
# DSC_3123.JPG        100%[===================>]  11.49M  19.3MB/s    in 0.6s
#
# 2021-07-31 17:42:12 (19.3 MB/s) - ‘training_images/DSC_3123.JPG’ saved [12044092/12044092]
#
# --2021-07-31 17:42:12--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616210/DSC_0599_832424bc-a1ac-4bee-85d9-a9d1554a063f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14139164 (13M) [image/jpeg]
# Saving to: ‘training_images/DSC_0599_832424bc-a1ac-4bee-85d9-a9d1554a063f.jpg’
#
# DSC_0599_832424bc-a 100%[===================>]  13.48M  17.9MB/s    in 0.8s
#
# 2021-07-31 17:42:13 (17.9 MB/s) - ‘training_images/DSC_0599_832424bc-a1ac-4bee-85d9-a9d1554a063f.jpg’ saved [14139164/14139164]
#
# --2021-07-31 17:42:13--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614104/A0084_AP_d902da93-0aa3-4fc2-87e5-55510dd6329c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8932987 (8.5M) [image/jpeg]
# Saving to: ‘training_images/A0084_AP_d902da93-0aa3-4fc2-87e5-55510dd6329c.jpg’
#
# A0084_AP_d902da93-0 100%[===================>]   8.52M  26.5MB/s    in 0.3s
#
# 2021-07-31 17:42:13 (26.5 MB/s) - ‘training_images/A0084_AP_d902da93-0aa3-4fc2-87e5-55510dd6329c.jpg’ saved [8932987/8932987]
#
# --2021-07-31 17:42:13--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615223/VIRB0142_c90f6746-b61a-416b-a039-6e467e0fe262.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3515012 (3.4M) [image/jpeg]
# Saving to: ‘training_images/VIRB0142_c90f6746-b61a-416b-a039-6e467e0fe262.jpg’
#
# VIRB0142_c90f6746-b 100%[===================>]   3.35M  21.1MB/s    in 0.2s
#
# 2021-07-31 17:42:13 (21.1 MB/s) - ‘training_images/VIRB0142_c90f6746-b61a-416b-a039-6e467e0fe262.jpg’ saved [3515012/3515012]
#
# --2021-07-31 17:42:13--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_92e3560c-e10b-417e-bbac-2d085ae495c1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5311036 (5.1M) [image/jpeg]
# Saving to: ‘training_images/TimCooli_92e3560c-e10b-417e-bbac-2d085ae495c1.jpg’
#
# TimCooli_92e3560c-e 100%[===================>]   5.06M  26.5MB/s    in 0.2s
#
# 2021-07-31 17:42:14 (26.5 MB/s) - ‘training_images/TimCooli_92e3560c-e10b-417e-bbac-2d085ae495c1.jpg’ saved [5311036/5311036]
#
# --2021-07-31 17:42:14--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_aa48a205-7758-4dee-9f0e-c21c05f64d8b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9507354 (9.1M) [image/jpeg]
# Saving to: ‘training_images/FEMA_Reg_aa48a205-7758-4dee-9f0e-c21c05f64d8b.jpg’
#
# FEMA_Reg_aa48a205-7 100%[===================>]   9.07M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:14 (60.6 MB/s) - ‘training_images/FEMA_Reg_aa48a205-7758-4dee-9f0e-c21c05f64d8b.jpg’ saved [9507354/9507354]
#
# --2021-07-31 17:42:14--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613899/DSC_3955_9d923157-ca0a-4b13-93c4-044deef15948.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13028229 (12M) [image/jpeg]
# Saving to: ‘training_images/DSC_3955_9d923157-ca0a-4b13-93c4-044deef15948.jpg’
#
# DSC_3955_9d923157-c 100%[===================>]  12.42M  26.5MB/s    in 0.5s
#
# 2021-07-31 17:42:15 (26.5 MB/s) - ‘training_images/DSC_3955_9d923157-ca0a-4b13-93c4-044deef15948.jpg’ saved [13028229/13028229]
#
# --2021-07-31 17:42:15--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_b946d6c1-8659-4242-8f07-7277c7af9f37.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8187567 (7.8M) [image/jpeg]
# Saving to: ‘training_images/FEMA_Reg_b946d6c1-8659-4242-8f07-7277c7af9f37.jpg.1’
#
# FEMA_Reg_b946d6c1-8 100%[===================>]   7.81M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:15 (65.0 MB/s) - ‘training_images/FEMA_Reg_b946d6c1-8659-4242-8f07-7277c7af9f37.jpg.1’ saved [8187567/8187567]
#
# --2021-07-31 17:42:15--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_3002_603979bf-aadf-4000-ac8b-a86ad5d6926d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10516620 (10M) [image/jpeg]
# Saving to: ‘training_images/DSC_3002_603979bf-aadf-4000-ac8b-a86ad5d6926d.jpg’
#
# DSC_3002_603979bf-a 100%[===================>]  10.03M  38.7MB/s    in 0.3s
#
# 2021-07-31 17:42:15 (38.7 MB/s) - ‘training_images/DSC_3002_603979bf-aadf-4000-ac8b-a86ad5d6926d.jpg’ saved [10516620/10516620]
#
# --2021-07-31 17:42:15--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614071/A0013_AP_2368e447-528a-4a91-8a84-9a82fb6bc468.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5814499 (5.5M) [image/jpeg]
# Saving to: ‘training_images/A0013_AP_2368e447-528a-4a91-8a84-9a82fb6bc468.jpg’
#
# A0013_AP_2368e447-5 100%[===================>]   5.54M  25.4MB/s    in 0.2s
#
# 2021-07-31 17:42:16 (25.4 MB/s) - ‘training_images/A0013_AP_2368e447-528a-4a91-8a84-9a82fb6bc468.jpg’ saved [5814499/5814499]
#
# --2021-07-31 17:42:16--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615474/Dec17201_98cf04f8-a750-4fde-86c7-37be4143b0dd.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6843354 (6.5M) [image/jpeg]
# Saving to: ‘training_images/Dec17201_98cf04f8-a750-4fde-86c7-37be4143b0dd.jpg.2’
#
# Dec17201_98cf04f8-a 100%[===================>]   6.53M  28.8MB/s    in 0.2s
#
# 2021-07-31 17:42:16 (28.8 MB/s) - ‘training_images/Dec17201_98cf04f8-a750-4fde-86c7-37be4143b0dd.jpg.2’ saved [6843354/6843354]
#
# --2021-07-31 17:42:16--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_17843620-67b9-46a5-a6e6-edd055d6396a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6195312 (5.9M) [image/jpeg]
# Saving to: ‘training_images/MarkBail_17843620-67b9-46a5-a6e6-edd055d6396a.jpg’
#
# MarkBail_17843620-6 100%[===================>]   5.91M  36.3MB/s    in 0.2s
#
# 2021-07-31 17:42:16 (36.3 MB/s) - ‘training_images/MarkBail_17843620-67b9-46a5-a6e6-edd055d6396a.jpg’ saved [6195312/6195312]
#
# --2021-07-31 17:42:16--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_e4b3cabe-8b4c-4901-9aeb-27eb553a84d0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7088090 (6.8M) [image/jpeg]
# Saving to: ‘training_images/DavidBen_e4b3cabe-8b4c-4901-9aeb-27eb553a84d0.jpg’
#
# DavidBen_e4b3cabe-8 100%[===================>]   6.76M  32.9MB/s    in 0.2s
#
# 2021-07-31 17:42:17 (32.9 MB/s) - ‘training_images/DavidBen_e4b3cabe-8b4c-4901-9aeb-27eb553a84d0.jpg’ saved [7088090/7088090]
#
# --2021-07-31 17:42:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_7028c846-94e5-4cf0-b169-f9772b920f64.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8915521 (8.5M) [image/jpeg]
# Saving to: ‘training_images/FEMA_Reg_7028c846-94e5-4cf0-b169-f9772b920f64.jpg’
#
# FEMA_Reg_7028c846-9 100%[===================>]   8.50M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:17 (61.4 MB/s) - ‘training_images/FEMA_Reg_7028c846-94e5-4cf0-b169-f9772b920f64.jpg’ saved [8915521/8915521]
#
# --2021-07-31 17:42:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614110/A0068_AP_2b40b402-9e36-4c7d-8a7b-1487de2a0771.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7275175 (6.9M) [image/jpeg]
# Saving to: ‘training_images/A0068_AP_2b40b402-9e36-4c7d-8a7b-1487de2a0771.jpg’
#
# A0068_AP_2b40b402-9 100%[===================>]   6.94M  --.-KB/s    in 0.1s
#
# 2021-07-31 17:42:17 (51.0 MB/s) - ‘training_images/A0068_AP_2b40b402-9e36-4c7d-8a7b-1487de2a0771.jpg’ saved [7275175/7275175]
#
# --2021-07-31 17:42:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614003/A0027V01_f278ce63-2dfd-43e8-8b4d-b2cf5a572501.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3510341 (3.3M) [image/jpeg]
# Saving to: ‘training_images/A0027V01_f278ce63-2dfd-43e8-8b4d-b2cf5a572501.jpg’
#
# A0027V01_f278ce63-2 100%[===================>]   3.35M  --.-KB/s    in 0.05s
#
# 2021-07-31 17:42:18 (61.8 MB/s) - ‘training_images/A0027V01_f278ce63-2dfd-43e8-8b4d-b2cf5a572501.jpg’ saved [3510341/3510341]
#
# --2021-07-31 17:42:18--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/613997/A0013Va0_06a1e1eb-a12b-4a96-ab23-f952cf28d76b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3482537 (3.3M) [image/jpeg]
# Saving to: ‘training_images/A0013Va0_06a1e1eb-a12b-4a96-ab23-f952cf28d76b.jpg’
#
# A0013Va0_06a1e1eb-a 100%[===================>]   3.32M  --.-KB/s    in 0.05s
#
# 2021-07-31 17:42:18 (65.3 MB/s) - ‘training_images/A0013Va0_06a1e1eb-a12b-4a96-ab23-f952cf28d76b.jpg’ saved [3482537/3482537]
#
# --2021-07-31 17:42:18--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_48a5e6ef-6dc1-495a-982e-a3b4bc968dda.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3502651 (3.3M) [image/jpeg]
# Saving to: ‘training_images/SteveBla_48a5e6ef-6dc1-495a-982e-a3b4bc968dda.jpg.1’
#
# SteveBla_48a5e6ef-6 100%[===================>]   3.34M  16.3MB/s    in 0.2s
#
# 2021-07-31 17:42:18 (16.3 MB/s) - ‘training_images/SteveBla_48a5e6ef-6dc1-495a-982e-a3b4bc968dda.jpg.1’ saved [3502651/3502651]
#
# --2021-07-31 17:42:18--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613608/DSC_1950_3dbf3847-f711-4c7d-bbc1-1966c2b41d3d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7748522 (7.4M) [image/jpeg]
# Saving to: ‘training_images/DSC_1950_3dbf3847-f711-4c7d-bbc1-1966c2b41d3d.jpg.2’
#
# DSC_1950_3dbf3847-f 100%[===================>]   7.39M  23.3MB/s    in 0.3s
#
# 2021-07-31 17:42:19 (23.3 MB/s) - ‘training_images/DSC_1950_3dbf3847-f711-4c7d-bbc1-1966c2b41d3d.jpg.2’ saved [7748522/7748522]
#
# --2021-07-31 17:42:19--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0027_a1fab081-a306-4c96-9807-d8ff2600f25e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3426880 (3.3M) [image/jpeg]
# Saving to: ‘training_images/VIRB0027_a1fab081-a306-4c96-9807-d8ff2600f25e.jpg.1’
#
# VIRB0027_a1fab081-a 100%[===================>]   3.27M  --.-KB/s    in 0.09s
#
# 2021-07-31 17:42:19 (37.0 MB/s) - ‘training_images/VIRB0027_a1fab081-a306-4c96-9807-d8ff2600f25e.jpg.1’ saved [3426880/3426880]
#
# FINISHED --2021-07-31 17:42:19--
# Total wall clock time: 28m 14s
# Downloaded: 4325 files, 29G in 16m 28s (30.5 MB/s)

# %%
scale = transforms.Resize(768)
crop = transforms.RandomCrop(512)
rotate = transforms.RandomRotation(20)
flip_demo = transforms.RandomHorizontalFlip(1) # flip with 100% chance just to demo
flip = transforms.RandomHorizontalFlip(p=0.5)
composed = transforms.Compose([scale,
                               crop,
                               rotate,
                               flip_demo])

# %%
# convenient function for showing the images
def show_image(image):
    plt.imshow(image)
    # pause a bit so that plots are updated
    plt.pause(0.01)

def convert_url_to_local_path(url):
    '''
    gets the location of the downloaded image
    '''
    return 'training_images/'+url.split('/')[-1]

class InfrastructureSampleDataset(Dataset):

    def __init__(self, metadata_csv, label_csv, transform = None):
        """
        Args:
            metadata_csv (string): Path to the csv file with metadata.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.infrastructure_sample_metadata = pd.read_csv(metadata_csv)
        # get the path in the shared directory
        self.infrastructure_sample_metadata['local_path'] = self.infrastructure_sample_metadata['url'].apply(convert_url_to_local_path)
        self.infrastructure_sample_label = pd.read_csv(label_csv)
        self.infrastructure_sample_data = pd.merge(self.infrastructure_sample_metadata, 
                                        self.infrastructure_sample_label,
                                       on="url")
        self.transform = transform
        
    def __len__(self):
        return len(self.infrastructure_sample_metadata)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        ## Load images from local directory. There is no need to redownload images to local machine. ##
        local_path = self.infrastructure_sample_metadata.iloc[idx]['local_path']
        url = self.infrastructure_sample_metadata.iloc[idx]['url']
        try:
            image = Image.fromarray(io.imread(local_path))
            img_name = local_path
        except:
            image = Image.fromarray(io.imread(url))
            img_name = url
        uuid = self.infrastructure_sample_data.iloc[idx, 1]
        timestamp = self.infrastructure_sample_data.iloc[idx, 2]
        gps_lat = self.infrastructure_sample_data.iloc[idx, 3]
        gps_lon = self.infrastructure_sample_data.iloc[idx, 4]
        gps_alt = self.infrastructure_sample_data.iloc[idx, 5]
        file_size = self.infrastructure_sample_data.iloc[idx, 6]
        width = self.infrastructure_sample_data.iloc[idx, 7]
        height = self.infrastructure_sample_data.iloc[idx, 8]
        label = torch.tensor(self.infrastructure_sample_data.iloc[idx, -4:].tolist(), dtype=torch.float)
        
        if self.transform:
            image = self.transform(image)

        sample = {'image': image, 
                  'image_name': img_name, 
                  'infrastructure_labels': label, 
                  'uuid': uuid, 
                  'timestamp': timestamp, 
                  'gps_lat': gps_lat, 
                  'gps_lon': gps_lon, 
                  'gps_alt': gps_alt, 
                  'orig_file_size': file_size, 
                  'orig_width': width, 
                  'orig_height': height}

        return sample
    def __str__(self):
        return self.infrastructure_sample_data.to_string()
    def get_labels(self):
        return torch.tensor(self.infrastructure_sample_data.iloc[:, -4:].values)
    def dataset(self):
        return self.infrastructure_sample_data
    def dataset_type(self):
        return type(self.infrastructure_sample_data)
    def get_columns(self):
        return self.infrastructure_sample_data.columns

# %%
infrastructure_sample_dataset = InfrastructureSampleDataset(metadata_csv = metadata_csv, label_csv = label_csv)

# %%
transformed_dataset = InfrastructureSampleDataset(metadata_csv = metadata_csv, 
                                       label_csv = label_csv, 
                                       transform = transforms.Compose([scale, 
                                                                       crop, 
                                                                       rotate, 
                                                                       flip, 
                                                                       transforms.ToTensor()]
                                                                     )
                                      )

# %%
# dataloader = DataLoader(transformed_dataset, batch_size=4, shuffle=True, num_workers=4)

# %%
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import DataLoader

batch_size = 16
test_split_ratio = .1
shuffle_dataset = True
random_seed = 42
# num_workers = 1

# Creating data indices for training and validation splits:
dataset_size = len(transformed_dataset)
indices = list(range(dataset_size))
split = int(np.floor(test_split_ratio * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, test_indices = indices[split:], indices[:split]

# Creating data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
test_sampler = SubsetRandomSampler(test_indices)

train_loader = torch.utils.data.DataLoader(transformed_dataset, batch_size=batch_size,
                                           sampler=train_sampler)
test_loader = torch.utils.data.DataLoader(transformed_dataset, batch_size=batch_size,
                                                sampler=test_sampler)

# %%
import torch.nn as nn
import torch.nn.functional as F
try:
    from cnn_finetune import make_model
except:
    # !pip install cnn-finetune
    from cnn_finetune import make_model

# %%
net = make_model('resnet50', num_classes=4, pretrained=True).cuda()

# %%
def pos_weights(labels):
    pos = labels.sum(axis=0)
    neg = torch.ones(labels.shape[-1])*labels.shape[0] - pos
    return (neg / pos).cuda()
print(pos_weights(transformed_dataset.get_labels()))
# Out:
# tensor([2.2655, 0.8917, 2.6083, 2.5726], device='cuda:0')

# %%
import torch.optim as optim

criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weights(transformed_dataset.get_labels()))
optimizer = optim.Adam(net.parameters(), lr=1e-4)

# %%
def get_checkpoint_path(epoch):
    return f'epoch_checkpoints/infrastructure_checkpoint_epoch{epoch}.pth'

torch.backends.cudnn.benchmark = True # flag for some GPU optimizations
starting_epoch = 1
additional_epochs = 5
net.train()
if starting_epoch > 1:
    net.load_state_dict(torch.load(get_checkpoint_path(starting_epoch-1)))
for epoch in range(starting_epoch, starting_epoch+additional_epochs):  # loop over the dataset multiple times
    running_loss, running_acc = 0.0, torch.tensor([0.0, 0.0, 0.0, 0.0]).cuda()
    print("start")
    for i, data in enumerate(train_loader, 0):
        # get the inputs; data is a list of [inputs, labels]
#         print(data['image'].shape)
#         print(data['damage_labels'])
#         print(data['damage_labels'].shape)
        inputs = data['image'].cuda()
        
#         labels = zip(data['damage:flood/water'], data['damage:rubble'], data['damage:smoke/fire'], data['damage:none']).cuda()
#         labels = data[['damage:flood/water','damage:rubble','damage:smoke/fire','damage:none']].cuda()
        labels = data['infrastructure_labels'].cuda()
        
#         labels = t.cuda()
        # casting int to long for loss calculation#
#         labels = labels.float()

        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
#         outputs = torch.sigmoid(net(inputs))
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        # print statistics
        
        running_loss += loss.item()
        
        pred = (torch.sigmoid(outputs) > 0.5).float()
        correct = (pred == labels).float().sum(axis=0)
        running_acc += correct
        print_freq = 1
        if (i+1) % print_freq == 0:  
            print(f'[Epoch {epoch}/{additional_epochs}, Batch {i+1}]    Loss: {running_loss/print_freq}    Binary Accuracies: {running_acc/(len(labels)*print_freq)}    Combined Accuracy: {(running_acc/(len(labels)*print_freq)).mean()}')
            running_loss, running_acc = 0.0, torch.tensor([0.0, 0.0, 0.0, 0.0]).cuda()
    # save the model
    PATH = get_checkpoint_path(epoch)
    torch.save(net.state_dict(), PATH)
print('Finished Training')
# Out:
# start
# [Epoch 1/5, Batch 1]    Loss: 0.8708738684654236    Binary Accuracies: tensor([0.6875, 0.6250, 0.6875, 0.6250], device='cuda:0')    Combined Accuracy: 0.65625
# [Epoch 1/5, Batch 2]    Loss: 0.7518773078918457    Binary Accuracies: tensor([0.8125, 0.7500, 0.8125, 0.6250], device='cuda:0')    Combined Accuracy: 0.75
# [Epoch 1/5, Batch 3]    Loss: 0.8640252947807312    Binary Accuracies: tensor([0.5625, 0.7500, 0.6875, 0.5000], device='cuda:0')    Combined Accuracy: 0.625
# [Epoch 1/5, Batch 4]    Loss: 1.0157722234725952    Binary Accuracies: tensor([0.3750, 0.5625, 0.5625, 0.4375], device='cuda:0')    Combined Accuracy: 0.484375
# [Epoch 1/5, Batch 5]    Loss: 0.716407299041748    Binary Accuracies: tensor([0.6875, 0.8125, 0.8125, 0.6875], device='cuda:0')    Combined Accuracy: 0.75
# [Epoch 1/5, Batch 6]    Loss: 0.7304362058639526    Binary Accuracies: tensor([0.7500, 0.6875, 0.8125, 0.5000], device='cuda:0')    Combined Accuracy: 0.6875
# [Epoch 1/5, Batch 7]    Loss: 0.8558260202407837    Binary Accuracies: tensor([0.5625, 0.6875, 0.6250, 0.6250], device='cuda:0')    Combined Accuracy: 0.625
# [Epoch 1/5, Batch 8]    Loss: 0.8587634563446045    Binary Accuracies: tensor([0.6250, 0.6875, 0.8125, 0.5625], device='cuda:0')    Combined Accuracy: 0.671875
# [Epoch 1/5, Batch 9]    Loss: 0.7929953932762146    Binary Accuracies: tensor([0.5000, 0.6875, 0.7500, 0.6250], device='cuda:0')    Combined Accuracy: 0.640625
# [Epoch 1/5, Batch 10]    Loss: 0.828507125377655    Binary Accuracies: tensor([0.5625, 0.7500, 0.6875, 0.4375], device='cuda:0')    Combined Accuracy: 0.609375
# [Epoch 1/5, Batch 11]    Loss: 0.7849324941635132    Binary Accuracies: tensor([0.6875, 0.7500, 0.6875, 0.5625], device='cuda:0')    Combined Accuracy: 0.671875

# %%
net.load_state_dict(torch.load(PATH))

outputs = net(images.cuda())
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % predicted[j].cpu()
                              for j in range(batch_size)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8cc31278d215> in <module>
#       1 net.load_state_dict(torch.load(PATH))
#       2
# ----> 3 outputs = net(images.cuda())
#       4 _, predicted = torch.max(outputs, 1)
#       5
#
# NameError: name 'images' is not defined

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in test_loader:
        images = data['image'].cuda()
        labels = data['damage:flood/water'].cuda()
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))

# %%
truth_labels = []
predicted_labels = []
with torch.no_grad():
    for data in test_loader:
        images = data['image'].cuda()
        labels = data['damage:flood/water'].cuda()
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        truth_labels.append(labels.cpu())
        predicted_labels.append(predicted.cpu())
truth_labels = np.concatenate([x.numpy() for x in truth_labels])
predicted_labels = np.concatenate([x.numpy() for x in predicted_labels])

# %%
import sklearn.metrics
confusion_matrix = sklearn.metrics.confusion_matrix(truth_labels, predicted_labels)
disp = sklearn.metrics.ConfusionMatrixDisplay(confusion_matrix, ['flood','no flood'])
disp.plot()
